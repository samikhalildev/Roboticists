# %%
! git clone https://github.com/vivekvivs42/DarkflowTry.git
! wget https://pjreddie.com/media/files/yolov2-tiny.weights
# Out:
# fatal: destination path 'DarkflowTry' already exists and is not an empty directory.
# --2019-10-04 15:04:55--  https://pjreddie.com/media/files/yolov2-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44948600 (43M) [application/octet-stream]
# Saving to: 'yolov2-tiny.weights.1’
#
# yolov2-tiny.weights  12%[=>                  ]   5.43M   954KB/s    eta 48s

# %%
cd ./DarkflowTry/
# Out:
# /content/DarkflowTry

# %%
! python3 setup.py build_ext --inplace
# Out:
# Compiling darkflow/cython_utils/nms.pyx because it changed.
# Compiling darkflow/cython_utils/cy_yolo2_findboxes.pyx because it changed.
# Compiling darkflow/cython_utils/cy_yolo_findboxes.pyx because it changed.
# [1/3] Cythonizing darkflow/cython_utils/cy_yolo2_findboxes.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/DarkflowTry/darkflow/cython_utils/cy_yolo2_findboxes.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# [2/3] Cythonizing darkflow/cython_utils/cy_yolo_findboxes.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/DarkflowTry/darkflow/cython_utils/cy_yolo_findboxes.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# ...

# %%
! pip install -e .
# Out:
# Obtaining file:///content/DarkflowTry
# ...
#   Running setup.py develop for darkflow
# ...

# %%
! pip install .
# Out:
# Processing /content/DarkflowTry
# ...
#   Created wheel for darkflow: filename=darkflow-1.0.0-cp36-cp36m-linux_x86_64.whl size=831118 sha256=13f4686c9ca963e1d2e5a316013be93ebf756c83b8fb236d2716ec074be36f38
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gye5we4s/wheels/55/bb/86/979f2313ff3fd359bb757f5c6a70432e87ab686d01a98b0fa1
# Successfully built darkflow
# ...
#   Found existing installation: darkflow 1.0.0
#     Can't uninstall 'darkflow'. No files were found to uninstall.
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from darkflow.net.build import TFNet
import cv2
# Out:
# WARNING:tensorflow:From /content/DarkflowTry/darkflow/net/build.py:15: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /content/DarkflowTry/darkflow/net/build.py:16: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From /content/DarkflowTry/darkflow/net/build.py:17: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /content/DarkflowTry/darkflow/net/build.py:18: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
#
# WARNING:tensorflow:From /content/DarkflowTry/darkflow/net/build.py:19: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.

# %%
ls
# Out:
# build/  darkflow/           flow*       preview.png  setup.py
# cfg/    darkflow.egg-info/  labels.txt  README.md    test/
# ckpt/   demo.gif            LICENSE     sample_img/  YOLO.ipynb

# %%
options = {"model": "/content/DarkflowTry/cfg/yolov2-tiny.cfg", 
           "load": "/content/yolov2-tiny.weights",
           "Train":False,
           "threshold":0.01}

# %%
tfnet = TFNet(options)
# Out:
# Parsing ./cfg/yolov2-tiny.cfg
# Parsing /content/DarkflowTry/cfg/yolov2-tiny.cfg
# Loading /content/yolov2-tiny.weights ...
# Successfully identified 44948600 bytes
# Finished in 0.006137371063232422s
#
# Building net ...
# WARNING:tensorflow:From /content/DarkflowTry/darkflow/net/build.py:105: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
# WARNING:tensorflow:From /content/DarkflowTry/darkflow/net/ops/baseop.py:70: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/DarkflowTry/darkflow/net/ops/baseop.py:71: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %%
import pprint as pp
original_img = cv2.imread("/content/gdrive/Shared drives/Data Driven Intelligent Robotics/Latest/istockphoto-185262648-612x612.jpg")
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
results = tfnet.return_predict(original_img)
print(results)
# Out:
# [{'label': 'person', 'confidence': 0.03265026, 'topleft': {'x': 22, 'y': 0}, 'bottomright': {'x': 582, 'y': 493}}, {'label': 'kite', 'confidence': 0.037373755, 'topleft': {'x': 262, 'y': 33}, 'bottomright': {'x': 464, 'y': 128}}, {'label': 'kite', 'confidence': 0.029716188, 'topleft': {'x': 195, 'y': 24}, 'bottomright': {'x': 495, 'y': 188}}, {'label': 'aeroplane', 'confidence': 0.010347506, 'topleft': {'x': 61, 'y': 0}, 'bottomright': {'x': 611, 'y': 546}}, {'label': 'spoon', 'confidence': 0.12658529, 'topleft': {'x': 134, 'y': 25}, 'bottomright': {'x': 469, 'y': 195}}, {'label': 'vase', 'confidence': 0.26883993, 'topleft': {'x': 30, 'y': 23}, 'bottomright': {'x': 582, 'y': 600}}, {'label': 'apple', 'confidence': 0.46576214, 'topleft': {'x': 25, 'y': 98}, 'bottomright': {'x': 591, 'y': 601}}, {'label': 'spoon', 'confidence': 0.06210123, 'topleft': {'x': 197, 'y': 77}, 'bottomright': {'x': 302, 'y': 176}}, {'label': 'bowl', 'confidence': 0.010748018, 'topleft': {'x': 148, 'y': 22}, '
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 15))
ax.imshow(original_img)

# %%
def boxing(original_img , predictions):
    newImage = np.copy(original_img)

    for result in predictions:
        top_x = result['topleft']['x']
        top_y = result['topleft']['y']

        btm_x = result['bottomright']['x']
        btm_y = result['bottomright']['y']

        confidence = result['confidence']
        label = result['label'] + " " + str(round(confidence, 3))
        
        if confidence > 0.04:
            newImage = cv2.rectangle(newImage, (top_x, top_y), (btm_x, btm_y), (255,0,0), 3)
            newImage = cv2.putText(newImage, label, (top_x, top_y-5), cv2.FONT_HERSHEY_COMPLEX_SMALL , 0.8, (0, 230, 0), 1, cv2.LINE_AA)
        
    return newImage

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.imshow(boxing(original_img, results))
